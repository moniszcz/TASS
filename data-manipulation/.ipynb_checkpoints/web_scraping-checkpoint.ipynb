# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
page = requests.get('https://en.wikipedia.org/wiki/List_of_main_battle_tanks_by_country')
soup = BeautifulSoup(page.content, 'lxml')

# print(soup.prettify())

# %%
tables=soup.findAll('table', class_='wikitable')
# tables

# %%
#ensure that in quantity column are ints only (without letter or symbols)
import re
pattern = re.compile('[0-9]+(,[0-9]+)?')
pattern.match('None')

# %%
A=[]
B=[]
C=[]
D=[]
E=[]
prev_country_name = ''

names = {
    'AMX 13': 'AMX-13', 'Type 69/79': 'Type 69', 'M1/M1A1/M1A2': 'M1A1', '\n': 'T-72', 'Leopard 2A4+ and 2A4MCAN': 'Leopard 2A4',
    'Leopard 2A4/2A5': 'Leopard 2A4', 'Leopard 2A5/A6/A6M/A7': 'Leopard 2A5', 'Leopard 1A3/A4': 'Leopard 1A3', 'Leopard 1A4/5': 'Leopard 1A4',
    'T72M1M': 'T-72', 'AMX-30B2': 'AMX-30', 'AMX-30G': 'AMX-30', 'AMX-30S': 'AMX-30', 'AMX-30V': 'AMX-30',
    'M-84A4 Sniper': 'M-84', 'M1A1 AIM Abrams': 'M1A1', 'M1A1 Abrams': 'M1A1', 'M48A5 MOLF': 'M48A5', 
    'M48A5 Patton': 'M48A5', 'M48A5K1': 'M48A5', 'M48A5T2': 'M48A5', 'M60A3 TTS':'M60A3', 'MBT 2000': 'MBT-2000', 
    'PT-91M': 'PT-91', 'T-34/85': 'T-34', 'T-54/55': 'T-54', 'T-54/T-55': 'T-54', 'T-55A/AM2': 'T-55', 'T-55AM2': 'T-55',
    'T-72 Aslan': 'T-72', 'T-72B Vitaz': 'T-72', 'T-72M4 CZ': 'T-72', 'T-72S': 'T-72', 'T-72M1': 'T-72', 'T-80U': 'T-80',
    'T-80UD': 'T-80', 'T-90A': 'T-90', 'Type 59G(BD) Durjoy': 'Type 59', 'Leopard 1A3': 'Leopard 1', 'Leopard 1A4': 'Leopard 1',
    'Leopard 2 Revolution': 'Leopard 2', 'Leopard 2A4NO': 'Leopard 2A4', 'Leopard 2A6 HEL': 'Leopard 2A6', 
    'Leopard 2A6E': 'Leopard 2A6', 'M48 Patton': 'M48', 'M60 A3': 'M60A3'
}

countries = {
    'Congo, Democratic Republic of': 'Democratic Republic of the Congo',
    'Congo, Republic of': 'Congo',
    'Republic of China (Taiwan)': 'Taiwan',
    'Korea, North': 'North Korea',
    'Korea, South': 'South Korea',
    'Macedonia, Republic of': 'Republic of Macedonia'
    
}
#for all tables on wikipedia page
for table in tables:
    #find all tr tags to access data
    rows = table.find_all('tr')
    for row in rows:
        #find all td tags - to acess all rows of wiki tables
        cells = row.find_all('td')
        if len(cells)==5:
            #in country column find links to wikipedia country pages
            clink = (cells[3].findAll('a'))
            quantity = str(cells[2].find(text=True))
            match = pattern.match(quantity)
            
            tank_name = str(cells[1].find(text=True))
            country_name = str(cells[0].find(text=True))
            #replace tank name with equivalent provided in dict 'names' - tidying data
            if tank_name in names:
                tank_name = names[tank_name]
            #replace country name with equivalent provided in dict 'countries' - tidying data
            if country_name in countries:
                country_name = countries[country_name]
            #append lists
            if match:
                A.append(country_name)
                prev_country_name = country_name
                B.append(tank_name)
                C.append(int(''.join(match.group(0).split(','))))
                D.append(clink[0].contents[0])
                E.append(cells[4].find(text=True))
        elif len(cells) == 1:
            country_name = str(cells[0].find(text=True))
            #replace country name with equivalent provided in dict 'countries' - tidying data
            if country_name in countries:
                country_name = countries[country_name]
            prev_country_name = country_name
        elif len(cells)==4:
            clink = (cells[2].findAll('a'))
            quantity = str(cells[1].find(text=True))
            match = pattern.match(quantity)
            
            tank_name = str(cells[0].find(text=True))
            
            if tank_name in names:
                tank_name = names[tank_name]
                
            if match:
                A.append(prev_country_name)
                B.append(tank_name)
                C.append(int(''.join(match.group(0).split(','))))
                D.append(clink[0].contents[0])
                E.append(cells[3].find(text=True))

# %%
import pandas as pd
#create dataframe
df=pd.DataFrame(A,columns=['Country '])
df['Type ']=B
df['Quantity (Estimated)']=C
df['Origin ']=D
# df
print(df.to_string())
# Out:
#                              Country                      Type   Quantity (Estimated)         Origin
# 0                         Afghanistan                      T-55                   601    Soviet Union
# 1                         Afghanistan                      T-62                   170    Soviet Union
# 2                             Algeria                      T-55                   270    Soviet Union
# 3                             Algeria                      T-62                   300    Soviet Union
# 4                             Algeria                      T-72                   325    Soviet Union
# 5                             Algeria                      T-90                   300          Russia
# 6                              Angola                      T-55                   200    Soviet Union
# 7                              Angola                      T-62                    50    Soviet Union
# 8                              Angola                      T-72                    50    Soviet Union
# 9                           Argentina  Tanque Argentino Mediano                   231       Argentina
# 10                            Armenia                      T-55                     5    Soviet Union
# 11                            Armenia                      T-72                   168    Soviet Union
# 12                            Armenia                      T-80                    20    Soviet Union
# 13                          Australia                      M1A1                    59   United States
# 14                            Austria                 Leopard 2                    56         Germany
# 15                         Azerbaijan                      T-90                   200          Russia
# 16                         Azerbaijan                      T-72                   420          Russia
# 17                         Azerbaijan                      T-55                   100    Soviet Union
# 18                            Bahrain                     M60A3                   180   United States
# 19                         Bangladesh                   Type 59                   474           China
# 20                         Bangladesh                   Type 69                    58           China
# 21                         Bangladesh                  MBT-2000                    44           China
# 22                            Belarus                      T-72                   446    Soviet Union
# 23                            Belarus                      T-80                    69    Soviet Union
# 24             Bosnia and Herzegovina                      M-84                    71      Yugoslavia
# 25             Bosnia and Herzegovina                    AMX-30                    50          France
# 26             Bosnia and Herzegovina                     M60A3                    85   United States
# 27             Bosnia and Herzegovina                      T-55                   142    Soviet Union
# 28                             Brazil              EE-T1 Osório                     2          Brazil
# 29                             Brazil                     M60A3                    91   United States
# 30                             Brazil                 Leopard 1                   127         Germany
# 31                             Brazil                 Leopard 1                   221         Germany
# 32                           Bulgaria                      T-72                   181    Soviet Union
# 33                           Cambodia                      T-55                   103    Soviet Union
# 34                           Cambodia                   Type 59                   200           China
# 35                             Canada                Leopard C2                   761         Germany
# 36                             Canada                 Leopard 2                   820         Germany
# 37                             Canada               Leopard 2A4                   680         Germany
# 38           Central African Republic                      T-55                     4    Soviet Union
# 39                               Chad                      T-55                    60    Soviet Union
# 40                              Chile                 Leopard 2                   172         Germany
# 41                              Chile                 Leopard 1                   100         Germany
# 42                              China                   Type 15                   200           China
# 232                        Tajikistan                      T-72                    44    Soviet Union
# 233                          Tanzania                   Type 59                    30           China
# 234                          Thailand                     M48A5                   105   United States
# 235                          Thailand                     M60A1                   178   United States
# 236                          Thailand                  BM Oplot                    31         Ukraine
# 237                          Thailand                      VT-4                    28           China
# 238                              Togo                      T-54                     4    Soviet Union
# 239                           Tunisia                     M60A3                    84   United States
# 240                            Turkey                     Altay                     4          Turkey
# 241                            Turkey               Leopard 2A4                   354         Germany
# 242                            Turkey               Leopard 1A3                   397         Germany
# 243                            Turkey                      M60T                   170   United States
# 244                            Turkey                     M60A3                   762   United States
# 245                            Turkey                     M48A5                   850   United States
# 246                      Turkmenistan                      T-72                   702    Soviet Union
# 247                      Turkmenistan                      T-90                    10          Russia
# 248                            Uganda                      T-55                    20    Soviet Union
# 249                            Uganda                      T-90                    44          Russia
# 250                           Ukraine                      T-64                  2271    Soviet Union
# 251                           Ukraine                      T-72                   180    Soviet Union
# 252                           Ukraine                      T-80                   215         Ukraine
# 253                           Ukraine                  BM Oplot                    10         Ukraine
# 254              United Arab Emirates                OF-40 Mk.2                    36           Italy
# 255              United Arab Emirates                    AMX-30                    45          France
# 256              United Arab Emirates                   Leclerc                   388          France
# 257                    United Kingdom              Challenger 2                   227  United Kingdom
# 258                     United States                     M60A3                   400   United States
# 259                     United States                      M1A1                  7970   United States
# 260                           Uruguay                     Ti-67                    15    Soviet Union
# 261                        Uzbekistan                      T-55                    80    Soviet Union
# 262                        Uzbekistan                      T-62                   170    Soviet Union
# 263                        Uzbekistan                      T-64                   100    Soviet Union
# 264                        Uzbekistan                      T-72                    70    Soviet Union
# 265                         Venezuela                    AMX-30                    81          France
# 266                         Venezuela                      T-72                    92    Soviet Union
# 267                           Vietnam                       M48                    20   United States
# 268                           Vietnam                   Type 59                   350           China
# 269                           Vietnam                      T-55                   900    Soviet Union
# 270                           Vietnam                      T-62                   200    Soviet Union
# 271                           Vietnam                      T-90                    64          Russia
# 272                             Yemen                     M60A1                    50   United States
# 273                             Yemen                      T-55                   450    Soviet Union
# 274                             Yemen                      T-62                   200    Soviet Union
# 275                             Yemen                      T-72                    60    Soviet Union
# 276                            Zambia                      T-55                    10    Soviet Union
# 277                          Zimbabwe                      T-54                    32    Soviet Union
# 278                          Zimbabwe                   Type 59                    35           China
# 279                          Zimbabwe                   Type 69                    10           China

# %%
#list of all countries available in data
countries_lst = A + D
# print(sorted(set(countries_lst)))

# %%
print(sorted(set(B)))
# Out:
# ['AMX-13', 'AMX-30', 'Al-Khalid', 'Al-Zarrar', 'Altay', 'Ariete', 'Arjun MBT', 'BM Oplot', 'Centurion', 'Challenger 1', 'Challenger 2', 'Chieftain MK3', 'Chonma-ho', 'EE-T1 Osório', 'K1', 'K2 Black Panther', 'Karrar', 'Khaled', 'Leclerc', 'Leopard 1', 'Leopard 1A3', 'Leopard 1A4', 'Leopard 2', 'Leopard 2A4', 'Leopard 2A5', 'Leopard 2A6', 'Leopard C2', 'Leopard Pz 87', 'Leopard Strv.122', 'M-55S', 'M-60 A3TTS', 'M-84', 'M-95 Degman', 'M1A1', 'M1A2', 'M4 Sherman', 'M41 Walker Bulldog', 'M48', 'M48A3K', 'M48A5', 'M60 Patton', 'M60A1', 'M60A3', 'M60T', 'MBT-2000', 'Magach 6', 'Magach 7', 'Merkava Mk.1', 'Merkava Mk.2', 'Merkava Mk.3', 'Merkava Mk.4', 'OF-40 Mk.2', 'Olifant 1A/1B', 'PT-91', 'Pokpung-ho', 'Ramses II', 'T-14 Armata', 'T-34', 'T-54', 'T-55', 'T-62', 'T-64', 'T-72', 'T-80', 'T-90', 'TR-580', 'TR-85', 'Tanque Argentino Mediano', 'Tariq', 'Ti-67', 'Type 10', 'Type 15', 'Type 59', 'Type 69', 'Type 74', 'Type 85-IIAP', 'Type 88', 'Type 90', 'Type 96', 'Type 99', 'VT-4', 'Vickers MBT', 'Vickers Mk 3', 'ZTZ88 MBT', 'Zulfiqar MBT']

# %%
#create database
import sqlalchemy as db
from sqlalchemy.orm import sessionmaker

from models import Alliance, Country, Tank

if __name__ == "__main__":
    engine = db.create_engine("sqlite:///main.db")

    Session = sessionmaker(bind=engine)

    session = Session()

# %%
#Create country table
for i in range(len(set(countries_lst))):
    country = Country(name=sorted(set(countries_lst))[i])
    session.add(country)
    session.commit()

# %%
#create dictionary to easily acess a country ID
dictionary = {}
for instance in session.query(Country).all():
    dictionary[instance.name] = instance.id

# %%
#Create tank table
for i in range(len(A)):
    tank = Tank(name=B[i], quantity=C[i], country_id=dictionary[A[i]], origin_id=dictionary[D[i]])
    session.add(tank)
    session.commit()

# %%
#import alliance dataset
import os
os.getcwd()
df1 = pd.read_csv("alliance_v4.1_by_directed.csv", dtype = {"dyad_st_year": int}, usecols = ['state_name1', 'state_name2', 'dyad_st_year', 'dyad_end_year'] )

#abandon countries which aren't in countries_lst
df_state_1 =  df1[df1['state_name1'].isin(sorted(set(countries_lst)))]

#abandon countries which aren't in countries_lst
df_state_2 =  df_state_1[df_state_1['state_name2'].isin(sorted(set(countries_lst)))]

#leave only alliances which have no ending year - they are still valid
df_end = df_state_2[~df_state_2['dyad_end_year'].notnull()]
df_end
# Out:
#          state_name1     state_name2  dyad_st_year  dyad_end_year
# 0     United Kingdom        Portugal          1816            NaN
# 1           Portugal  United Kingdom          1816            NaN
# 1830      Mauritania         Somalia          1974            NaN
# 1832      Mauritania         Morocco          1973            NaN
# 1833      Mauritania         Algeria          1973            NaN
# ...              ...             ...           ...            ...
# 6435         Belarus          Russia          2009            NaN
# 6436          Russia         Armenia          2010            NaN
# 6437         Armenia          Russia          2010            NaN
# 6440           Egypt          Israel          1979            NaN
# 6441          Israel           Egypt          1979            NaN
#
# [1492 rows x 4 columns]

# %%
end_year_lst = df_end['dyad_end_year'].tolist()
country_1_lst = df_end['state_name1'].tolist()
country_2_lst = df_end['state_name2'].tolist()
start_year_lst = df_end['dyad_st_year'].tolist()

# %%
# Create Alliance table
for i in range(len(country_1_lst)):
    alliance = Alliance(country1_id=dictionary[country_1_lst[i]], country2_id=dictionary[country_2_lst[i]], start_year=start_year_lst[i], end_year=end_year_lst[i])
    session.add(alliance)
    session.commit()

# %%
session.close()
